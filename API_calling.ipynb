# %% [markdown]
# <a href="https://colab.research.google.com/github/anshulkr69/learning-to-make-machine-learn/blob/main/API_calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

url = "https://real-time-amazon-data.p.rapidapi.com/best-sellers"

querystring = {"category":"software","type":"BEST_SELLERS","page":"1","country":"US"}

headers = {
	"x-rapidapi-key": "0a42e62a3amsh56fa6292dd9bbb3p1bfb3ajsn3f9e1de24a60",
	"x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

df1=pd.DataFrame(response.json()['data']['best_sellers'])
df1['category']=response.json()['data']['category_name']

# %%
df1
# Out:
#     rank        asin                                      product_title  \
# 0      1  B0FWV56H48  TurboTax Deluxe Desktop Edition 2025, Federal ...
# 1      2  B0DGVQMGBB  Microsoft Office Home 2024 | Classic Office Ap...
# 2      3  B0DHYGWYJ6  [OLD VERSION] TurboTax Deluxe 2024 Tax Softwar...
# 3      4  B07Q33SJDW  Norton 360 Deluxe, Antivirus software for 5 De...
# 4      5  B07G8SQ2S3  Bitdefender Total Security 2026 – Complete Ant...
# 5      6  B07Q8JGCSQ  Norton 360 Deluxe, Antivirus software for 3 De...
# 6      7  B0FRPW868X  H&R Block Tax Software Deluxe + State 2025 Win...
# 7      8  B0BB2N69J8  McAfee Total Protection 3-Device | AntiVirus S...
# 8      9  B09MYJ1R6L  Microsoft System Builder | Windоws 11 Home | I...
# 9     10  B0D9HYGCLQ  NordVPN Basic, 10 Devices, 1-Year, Premium VPN...
# 10    11  B092M5G1G7  Mullvad VPN | 12 Months for 5 Devices | No-Log...
# 11    12  B09WCTTXQ6  Windows 11 Pro Upgrade, from Windows 11 Home (...
# ...

# %%
df1.shape
# Out:
# (50, 10)

# %%
df1.to_csv('top_seller')

# %%
df1=df1.set_index('rank')
