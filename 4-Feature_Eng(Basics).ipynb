# %% [markdown]
# <a href="https://colab.research.google.com/github/anshulkr69/learning-to-make-machine-learn/blob/main/Feature_Eng(Basics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Feature engineering is the process of using domain knowledge to extract features from raw data. these feature can be used to improve the performance of machine learning algorithms.
#
#
#
# ```
# bekar algo ko badhiya features doge toh better perform krege as compared to good algo with
# bad features.
# ```

# %% [markdown]
# # What come under feature eng.:
#
# ```
# 1. FEATURE TRANSFORMATION:
#     a. missing value imputation
#     b. handling categorical features
#     c. outlier detection
#     d. feature scaling
# ```
#
#
#
# ```
# 2. FEATURE CONSTRUCTION
# ```
#
#
# ```
# 3. FEATURE SELECTION
# ```
#
#
#
# ```
# 4. FEATURE EXTRACTION
# ```

# %% [markdown]
# ### 1(a) Missing values
# multiple cheez kr skte hain to fix this
# like removing missing value if they are not too many or replacing them

# %% [markdown]
# ### 1(b) Handling categorical values
# iske liye encoding perform krte hain because objects smjhna mushkil.

# %% [markdown]
# ### 1(c) Outlier Detection
# this is very important because if we don't perform this our algo/model can go very off no it is necessary to eliminate it.

# %% [markdown]
# ### 1(d) Feature scaling
# if the scales of various variables vary too much, it is necessary to scale up/down the data to precisely fit the model. This affects KNN severely.

# %% [markdown]
# ### 2. Feature construction
# Jo data aya h us se features bnane ka kaam krte hain is process mein
# Ismein hi feature reduction bhi ata h, jaise 2 feature ko ek mein redice kr dena. Eg.: rooms+bedroom => sqft. area

# %% [markdown]
# ### 3. Feature Selection
# ismein useful features select krte hain so that model doesn't need to evaluate parameters for useless features.

# %% [markdown]
# ### 4. Feature Extraction
# This is for further use but this is use to condense down the data.
# jaise number predict krna h agar 28x28 pixel ke image mein we can crop it to that part where the actual number is.
